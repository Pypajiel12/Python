# %%
import pandas as pd    #question 1.1          
import webbrowser
import seaborn as sns
from IPython.display import HTML
import urllib.request
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#1.2
data = pd.read_csv("data.csv")
data
# Out:
#        Unnamed: 0   Price                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
France = data[data.Nationality == 'France' ]

# %%
Italy = data[data.Nationality == 'Italy' ]

# %%
spain = data[data.Nationality == 'Spain' ]

# %%
brazil = data[data.Nationality == 'Brazil']

# %%
Argentina = data[data.Nationality == 'Argentina' ]

# %%
Germany = data[data.Nationality == 'Germany']

# %%
England = data[data.Nationality == 'England']

# %%
Nationalité = [France , Italy , spain, brazil  , Argentina , Germany, England]

# %%
plt.plot(France.Potential)
plt.show()

# %%
England
# Out:
#        Unnamed: 0   Price            Name  Age  \
# 16             16  202126         H. Kane   24
# 60             60  202652     R. Sterling   23
# 117           117  211117         D. Alli   22
# 135           135  188377       K. Walker   28
# 180           180  204935     J. Pickford   24
# ...           ...     ...             ...  ...
# 18198       18198  242844      J. Livesey   18
# 18202       18202  238813    J. Lundstram   19
# 18204       18204  241638       B. Worman   16
# 18205       18205  246268  D. Walker-Rice   17
# 18206       18206  246269       G. Nugent   16
#
#                                                 Photo Nationality  \
# 16     https://cdn.sofifa.org/players/4/19/202126.png     England
# 60     https://cdn.sofifa.org/players/4/19/202652.png     England
# 117    https://cdn.sofifa.org/players/4/19/211117.png     England
# 135    https://cdn.sofifa.org/players/4/19/188377.png     England
# ...
